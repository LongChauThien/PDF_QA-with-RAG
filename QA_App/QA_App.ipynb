# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CS221/QA_App
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CS221/QA_App'
# /content

# %%
# !pip install -r requirements.txt

# %%
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python==0.2.28

# %%
# !npm install localtunnel

# %%
# !streamlit run app.py &>logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# ^C
